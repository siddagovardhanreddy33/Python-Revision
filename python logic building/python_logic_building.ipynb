# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # 🧠 PYTHON LOGIC BUILDING — 100 QUESTIONS ROADMAP
#
# ## 🟢 LEVEL 1: BASICS (1–20)
#
# Focus: syntax, conditions, loops, input/output
#
# 1. Check if a number is even or odd
# 2. Find largest of 3 numbers
# 3. Swap two numbers (with & without temp)
# 4. Check leap year
# 5. Print multiplication table
# 6. Sum of first N natural numbers
# 7. Factorial of a number
# 8. Reverse a number
# 9. Count digits in a number
# 10. Check palindrome number
# 11. Fibonacci series (N terms)
# 12. Armstrong number
# 13. Prime number check
# 14. Print all primes in range
# 15. GCD & LCM
# 16. Sum of digits
# 17. Convert decimal to binary
# 18. Find ASCII value of character
# 19. Simple calculator using if-else
# 20. Menu-driven program
#
# ---
#
# ## 🟡 LEVEL 2: STRINGS (21–35)
#
# High interview weight 🚨
#
# 21. Reverse a string
# 22. Check palindrome string
# 23. Count vowels/consonants
# 24. Remove spaces
# 25. Find frequency of characters
# 26. First non-repeating character
# 27. Check anagram
# 28. Capitalize first letter of each word
# 29. Remove duplicates from string
# 30. Longest substring without repeating chars ⭐
# 31. Count words in string
# 32. Replace substring
# 33. Check rotation of string
# 34. String compression (aaabb → a3b2)
# 35. Print all substrings
#
# ---
#
# ## 🔵 LEVEL 3: LISTS & ARRAYS (36–55)
#
# Most asked in interviews 🔥
#
# 36. Find largest/smallest element
# 37. Second largest element ⭐
# 38. Remove duplicates
# 39. Rotate list (left/right)
# 40. Merge two lists
# 41. Find intersection of lists
# 42. Find union of lists
# 43. Count frequency of elements
# 44. Kadane’s Algorithm (max subarray sum) ⭐
# 45. Move zeros to end
# 46. Sort without built-in sort
# 47. Binary search ⭐
# 48. Linear search
# 49. Find missing number
# 50. Find duplicates in array
# 51. Pair with given sum ⭐
# 52. Triplet sum problem
# 53. Subarray with given sum
# 54. Product of array except self ⭐
# 55. Two sum problem ⭐
#
# ---
#
# ## 🟣 LEVEL 4: DICTIONARIES & SETS (56–65)
#
# 56. Count frequency using dict
# 57. Merge two dictionaries
# 58. Sort dictionary by values
# 59. Invert a dictionary
# 60. Group anagrams ⭐
# 61. Find common keys in dicts
# 62. Remove duplicates using set
# 63. Check subset
# 64. Find symmetric difference
# 65. Character frequency using dict
#
# ---
#
# ## 🟠 LEVEL 5: FUNCTIONS & RECURSION (66–75)
#
# 66. Recursive factorial
# 67. Recursive Fibonacci
# 68. Power function (x^n)
# 69. Sum of digits (recursion)
# 70. Reverse string (recursion)
# 71. Tower of Hanoi ⭐
# 72. Generate permutations
# 73. Generate combinations
# 74. Backtracking basics
# 75. N-Queens problem ⭐
#
# ---
#
# ## 🔴 LEVEL 6: OOP (76–85)
#
# Important for freshers + projects
#
# 76. Create class & object
# 77. Constructor example
# 78. Inheritance example
# 79. Multiple inheritance
# 80. Method overriding
# 81. Operator overloading
# 82. Encapsulation example
# 83. Abstraction example
# 84. Class vs static methods
# 85. Build mini banking system ⭐
#
# ---
#
# ## ⚫ LEVEL 7: FILE HANDLING & EXCEPTIONS (86–90)
#
# 86. Read/write file
# 87. Count words in file
# 88. Copy file contents
# 89. Exception handling (try-except)
# 90. Custom exception
#
# ---
#
# ## 🟤 LEVEL 8: ADVANCED LOGIC (91–100)
#
# High-value interview problems 🚨🔥
#
# 91. LRU Cache implementation ⭐
# 92. Sliding window maximum ⭐
# 93. Longest increasing subsequence ⭐
# 94. Merge intervals ⭐
# 95. Detect cycle in list
# 96. Top K frequent elements ⭐
# 97. Median of two sorted arrays ⭐
# 98. Word break problem ⭐
# 99. Minimum window substring ⭐
# 100. Design URL shortener ⭐
