# %% [markdown]
# ## 🔴 LEVEL 6: OOP (76–85)
#
# Important for freshers + projects
#
# 76. Create class & object
# 77. Constructor example
# 78. Inheritance example
# 79. Multiple inheritance
# 80. Method overriding
# 81. Operator overloading
# 82. Encapsulation example
# 83. Abstraction example
# 84. Class vs static methods
# 85. Build mini banking system ⭐
