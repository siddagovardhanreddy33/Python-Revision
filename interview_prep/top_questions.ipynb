# %% [markdown]
# # 🔥 TOP 50 PYTHON INTERVIEW QUESTIONS (HIGH-WEIGHT TOPICS)
#
# ---
#
# # 🟡 STRINGS (1–10) — *VERY IMPORTANT*
#
# Core patterns: hashing, sliding window, frequency count
#
# 1. Longest substring without repeating characters ⭐
# 2. Valid palindrome (ignore special chars)
# 3. Group anagrams ⭐
# 4. Minimum window substring ⭐🔥
# 5. Longest palindromic substring ⭐
# 6. String compression (aabcc → a2b1c2)
# 7. First non-repeating character
# 8. Check if two strings are isomorphic
# 9. Check rotation of string
# 10. Implement `strStr()` (substring search)
#
# ---
#
# # 🔵 ARRAYS (11–20) — *MUST DO*
#
# Core patterns: prefix sum, sorting, greedy
#
# 11. Two Sum ⭐🔥
# 12. Best time to buy & sell stock ⭐
# 13. Maximum subarray (Kadane’s Algorithm) ⭐🔥
# 14. Product of array except self ⭐
# 15. Find duplicate number
# 16. Merge sorted arrays
# 17. Move zeros to end
# 18. Container with most water ⭐
# 19. Find missing number
# 20. Rotate array ⭐
#
# ---
#
# # 🟣 HASHMAPS / DICTIONARIES (21–30)
#
# Core: frequency map, fast lookup
#
# 21. Top K frequent elements ⭐🔥
# 22. Subarray sum equals K ⭐
# 23. Longest consecutive sequence ⭐
# 24. Two sum using hashmap
# 25. Group shifted strings
# 26. Count pairs with given sum
# 27. Find all anagrams in a string ⭐
# 28. Intersection of two arrays
# 29. Isomorphic strings
# 30. Majority element ⭐
#
# ---
#
# # 🟠 SLIDING WINDOW (31–36) — *HIGHLY ASKED*
#
# Core: fixed & variable window
#
# 31. Maximum sum subarray of size K
# 32. Longest substring with K unique characters ⭐
# 33. Minimum window substring ⭐🔥
# 34. Sliding window maximum ⭐🔥
# 35. Count occurrences of anagrams
# 36. Longest repeating character replacement ⭐
#
# ---
#
# # 🟢 TWO POINTER (37–42)
#
# Core: sorted arrays, optimization
#
# 37. Valid palindrome II
# 38. Two sum II (sorted array)
# 39. 3Sum problem ⭐🔥
# 40. Remove duplicates from sorted array
# 41. Trapping rain water ⭐🔥
# 42. Container with most water
#
# ---
#
# # 🔴 RECURSION + BACKTRACKING (43–48)
#
# Core: tree of choices, exponential search
#
# 43. Generate all subsets ⭐
# 44. Generate permutations ⭐
# 45. Combination sum ⭐🔥
# 46. N-Queens ⭐🔥
# 47. Word search in grid ⭐
# 48. Palindrome partitioning
#
# ---
#
# # ⚫ BASIC OOP (49–50)
#
# Core: real-world modeling
#
# 49. Design a class for **LRU Cache** ⭐🔥
# 50. Design a simple **Banking System** (deposit, withdraw, balance)
#
# ---
#
# # 🎯 MUST-DO (TOP 15 FROM ABOVE)
#
# If you’re short on time, DO THESE FIRST:
#
# * Longest substring without repeating chars
# * Minimum window substring
# * Two Sum
# * Kadane’s Algorithm
# * Product of array except self
# * Top K frequent elements
# * Subarray sum equals K
# * Sliding window maximum
# * 3Sum
# * Trapping rain water
# * Combination sum
# * N-Queens
# * Generate permutations
# * LRU Cache
# * Longest palindromic substring
#
# ---
#
# # 🧠 HOW INTERVIEWERS THINK (IMPORTANT)
#
# They don’t care if you memorize—they check:
#
# * Can you identify pattern? (window / hashmap / recursion)
# * Can you optimize brute force?
# * Can you explain clearly?
